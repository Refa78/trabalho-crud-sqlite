# %%
# não usar , estou ainda terminando
#Feito por José
import sqlite3
import os
import psycopg2


def menu_banco():
    print("\n===== Escolha seu banco de dados a ser usado =====")
    print("1 - Sqlite")
    print("2 - PostGree")
    print("0 - Sair")

# -----------------------   criando base em POSTGREE  -----------------------

def criando_postgree():
     
     while True:
            print("Digite o host do servidor postgree")
            host = input('Digite o endereço do banco')
            print("Digite o nome da Database")
            dataBase = input("Digite o nome da base de dados")
            print("Digite o login da base")
            login = input("Digite o login do banco")
            print("Digite o senha da basede dados")
            Senha = input("Digite a senha")
            try:
               conexao = psycopg2.connect(host=host,database=dataBase,user=login,password=Senha)
               cursor = conexao.cursor()
               print("Funcionou a base", type(cursor))
               print("conectou postgree")
               break
            except psycopg2.OperationalError as e:
              print(f"Erro ao conectar: {e}")
              print("Digite 0 para Sair ou aperte enter para continuar")
              sair= input("Digite zero para sair do sistema ou enter para continuar")

              if sair == "0":
                 return
              
    



# -----------------------   criando base em SQLITE  -----------------------

def criando_sqlite():
    conexao = sqlite3.connect("sistema.db")
    cursor = conexao.cursor()

    cursor.execute("""
        CREATE TABLE IF NOT EXISTS alunos (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            nome TEXT NOT NULL,
            email TEXT NOT NULL,
            curso TEXT NOT NULL
        )
    """)
    conexao.commit()
    conexao.close()


    

def Config_Database():
    if os.path.exists('conexao.ini'):
        print('existe ini')
        #conecta_postgree()

    elif os.path.exists('sistema.db'):
        print('conectou sistema.db')
        return sqlite3.connect("sistema.db")

    else:

        print("verificando base de dados")
        print("Database Inexistente!....")
        print('Dando inicio a instalação do banco de dados') 

        while True:
            menu_banco()
            opcao = input("Escolha uma opção: ")

            if opcao == "1":
                criando_sqlite()
                Config_Database()
                return

            elif opcao == "2":
                criando_postgree()
            elif opcao == "0":
                print("Saindo do sistema...")
                break
            else:
                print("Opção inválida. Tente novamente.")


 
# Feito por Jose


def menu_banco():
    print("\n===== Escolha seu banco de dados a ser usado =====")
    print("1 - Sqlite")
    print("2 - PostGree")
    print("0 - Sair")

# -----------------------   criando base em POSTGREE  -----------------------

def criando_postgree():
    while True:
        print("Digite o host do servidor postgree")
        host = input("Digite o endereco do banco")
        print("Digite o nome da Database")
        dataBase = input("Digite o nome da base de dados")
        print("Digite o login da base")
        login = input("Digite o login do banco")
        print("Digite o senha da basede dados")
        Senha = input("Digite a senha")
        try:
            conexao = psycopg2.connect(host=host, database=dataBase, user=login, password=Senha)
            cursor = conexao.cursor()
            print("Funcionou a base", type(cursor))
            print("conectou postgree")
            break
        except psycopg2.OperationalError as e:
            print(f"Erro ao conectar: {e}")
            print("Digite 0 para Sair ou aperte enter para continuar")
            sair = input("Digite zero para sair do sistema ou enter para continuar")

            if sair == "0":
                return


# -----------------------   criando base em SQLITE  -----------------------

def criando_sqlite():
    conexao = sqlite3.connect("sistema.db")
    cursor = conexao.cursor()

    cursor.execute("""
        CREATE TABLE IF NOT EXISTS alunos (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            nome TEXT NOT NULL,
            email TEXT NOT NULL,
            curso TEXT NOT NULL
        )
    """)
    conexao.commit()
    conexao.close()


def Config_Database():
    if os.path.exists("conexao.ini"):
        print("existe ini")
        # conecta_postgree()

    elif os.path.exists("sistema.db"):
        print("conectou sistema.db")
        return sqlite3.connect("sistema.db")

    else:
        print("verificando base de dados")
        print("Database Inexistente!....")
        print("Dando inicio a instalacao do banco de dados")

        while True:
            menu_banco()
            opcao = input("Escolha uma opcao: ")

            if opcao == "1":
                criando_sqlite()
                Config_Database()
                return
            elif opcao == "2":
                criando_postgree()
            elif opcao == "0":
                print("Saindo do sistema...")
                break
            else:
                print("Opcao invalida. Tente novamente.")


Config_Database()
# Out:
# verificando base de dados
# Database Inexistente!....
# Dando inicio a instalacao do banco de dados
#
# ===== Escolha seu banco de dados a ser usado =====
# 1 - Sqlite
# 2 - PostGree
# 0 - Sair
# Digite o host do servidor postgree
# Digite o nome da Database
# Digite o login da base
# Digite o senha da basede dados
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[14], line 183
#     179             else:
#     180                 print("Opcao invalida. Tente novamente.")
#     181
#     182
# --> 183 Config_Database()
#     184
#     185
#     186
#
# Cell In[14], line 175, in Config_Database()
#     171                 criando_sqlite()
#     172                 Config_Database()
#     173                 return
#     174             elif opcao == "2":
# --> 175                 criando_postgree()
#     176             elif opcao == "0":
#     177                 print("Saindo do sistema...")
#     178                 break
#
# Cell In[14], line 125, in criando_postgree()
#     121             cursor = conexao.cursor()
#     122             print("Funcionou a base", type(cursor))
#     123             print("conectou postgree")
#     124             break
# --> 125         except psycopg2.OperationalError as e:
#     126             print(f"Erro ao conectar: {e}")
#     127             print("Digite 0 para Sair ou aperte enter para continuar")
#     128             sair = input("Digite zero para sair do sistema ou enter para continuar")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     132     kwasync['async_'] = kwargs.pop('async_')
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#     137     conn.cursor_factory = cursor_factory
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe1 in position 128: invalid continuation byte
